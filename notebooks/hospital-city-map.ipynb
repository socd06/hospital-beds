# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
df = pd.read_csv("../data/usa-hospital-beds_dataset_usa-hospital-beds.csv")
df.head()
# Out:
#             X          Y  OBJECTID  \
# 0 -112.066157  33.495498         1
# 1 -110.965885  32.181263         2
# 2 -119.779742  36.773323         3
# 3  -72.957610  41.284400         4
# 4  -75.606533  39.740206         5
#
#                                        HOSPITAL_NAME HOSPITAL_TYPE  \
# 0  Phoenix VA Health Care System (AKA Carl T Hayd...   VA Hospital
# 1             Southern Arizona VA Health Care System   VA Hospital
# 2           VA Central California Health Care System   VA Hospital
# 3  VA Connecticut Healthcare System - West Haven ...   VA Hospital
# 4                       Wilmington VA Medical Center   VA Hospital
#
#                HQ_ADDRESS HQ_ADDRESS1     HQ_CITY HQ_STATE  HQ_ZIP_CODE  ...  \
# 0  650 E Indian School Rd         NaN     Phoenix       AZ        85012  ...
# 1          3601 S 6th Ave         NaN      Tucson       AZ        85723  ...
# 2      2615 E Clinton Ave         NaN      Fresno       CA        93703  ...
# 3        950 Campbell Ave         NaN  West Haven       CT         6516  ...
# 4       1601 Kirkwood Hwy         NaN  Wilmington       DE        19805  ...
#
#   CNTY_FIPS     FIPS  NUM_LICENSED_BEDS  NUM_STAFFED_BEDS  NUM_ICU_BEDS  \
# 0      13.0   4013.0               62.0              62.0             0
# 1      19.0   4019.0              295.0             295.0             2
# 2      19.0   6019.0               54.0              54.0             2
# 3       9.0   9009.0              216.0             216.0             1
# 4       3.0  10003.0               62.0              62.0             0
#
#    ADULT_ICU_BEDS  PEDI_ICU_BEDS  BED_UTILIZATION  \
# 0               0            NaN              NaN
# 1               2            NaN              NaN
# 2               2            NaN              NaN
# 3               1            NaN              NaN
# 4               0            NaN              NaN
#
#    Potential_Increase_In_Bed_Capac  AVG_VENTILATOR_USAGE
# 0                                0                   0.0
# 1                                0                   2.0
# 2                                0                   2.0
# 3                                0                   2.0
# 4                                0                   1.0
#
# [5 rows x 23 columns]

# %%
features = ["X", "Y", "BED_UTILIZATION","HOSPITAL_NAME","HQ_ADDRESS","HQ_CITY"]
sub_df = df[features]

# and we get rid of NA values
clean_sub_df = sub_df.dropna()
clean_sub_df.head()
# Out:
#             X          Y  BED_UTILIZATION  \
# 9  -90.105308  32.325487         0.279868
# 17 -86.451938  32.463778         0.623113
# 18 -87.888307  30.519027         0.770054
# 19 -87.785172  30.903945         0.285131
# 20 -85.156357  31.888764         0.378721
#
#                                         HOSPITAL_NAME           HQ_ADDRESS  \
# 9   Merit Health River Oaks (FKA River Oaks Hospit...   1030 River Oaks Dr
# 17                        Prattville Baptist Hospital    124 S Memorial Dr
# 18                                    Thomas Hospital       750 Morphy Ave
# 19                            North Baldwin Infirmary        1815 Hand Ave
# 20                             Medical Center Barbour  820 W Washington St
#
#         HQ_CITY
# 9       Flowood
# 17   Prattville
# 18     Fairhope
# 19  Bay Minette
# 20      Eufaula

# %%
# TODO: Filter dataframe by city: HQ_CITY
# using Denver as an starter example
is_city = clean_sub_df["HQ_CITY"] == "Denver"

# %%
city_df = clean_sub_df[is_city]
city_df
# Out:
#                X          Y  BED_UTILIZATION  \
# 600  -104.941121  39.739074         0.021347
# 601  -104.934050  39.732185         0.488082
# 602  -104.974820  39.670039         0.512500
# 603  -104.971727  39.746188         0.635472
# 604  -104.991080  39.728240         0.641354
# 605  -104.966517  39.747048         0.597209
# 4574 -105.035091  39.743546         0.628072
# 5107 -105.033615  39.641503         0.932818
# 5333 -104.964486  39.746245         0.394964
#
#                                           HOSPITAL_NAME         HQ_ADDRESS  \
# 600                              National Jewish Health    1400 Jackson St
# 601                                 Rose Medical Center     4567 E 9th Ave
# 602                           Porter Adventist Hospital  2525 S Downing St
# 603   Saint Joseph Hospital (FKA Exempla St Joseph H...    1375 E 19th Ave
# 604                           Denver Health Main Campus     777 Bannock St
# 605                Presbyterian/St Lukes Medical Center    1719 E 19th Ave
# 4574  PAM Specialty Hospital of Denver (FKA Colorado...      1690 Meade St
# 5107        Colorado Mental Health Institute Fort Logan  3520 W Oxford Ave
# 5333                          Kindred Hospital - Denver     1920 N High St
#
#      HQ_CITY
# 600   Denver
# 601   Denver
# 602   Denver
# 603   Denver
# 604   Denver
# 605   Denver
# 4574  Denver
# 5107  Denver
# 5333  Denver

# %%
# TODO
# We only want to display hospitals where bed utilization is below 70%

# %%
#Define coordinates of where we want to center our map
boulder_coords = [39.670039, -104.974820]

#Create the map
my_map = folium.Map(location = boulder_coords, zoom_start = 10)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Prepare dataframe data to add map markers
# TODO make a list of [X, Y] coordinates

# Select X and Y features from cleaned dataframe
coord_features = ["Y","X"]

# Make a new dataframe out of the coordinate features
coords_df = city_df[coord_features]

# and view the first data points to make sure it worked
coords_df.head()
# Out:
#              Y           X
# 600  39.739074 -104.941121
# 601  39.732185 -104.934050
# 602  39.670039 -104.974820
# 603  39.746188 -104.971727
# 604  39.728240 -104.991080

# %%
# Make a list of coordinates
coords_list = coords_df.values.tolist()

# do a sanity check
coords_list[0]
# Out:
# [39.739073600000005, -104.94112120000001]

# %%
# Make a list of Hospital Names
hnames_df = city_df['HOSPITAL_NAME']
hnames_list = hnames_df.to_list()
hnames_list
# Out:
# ['National Jewish Health',
#  'Rose Medical Center',
#  'Porter Adventist Hospital',
#  'Saint Joseph Hospital (FKA Exempla St Joseph Hospital)',
#  'Denver Health Main Campus',
#  'Presbyterian/St Lukes Medical Center',
#  'PAM Specialty Hospital of Denver (FKA Colorado Acute Long Term Hospital)',
#  'Colorado Mental Health Institute Fort Logan',
#  'Kindred Hospital - Denver']

# %%
capacity_df = city_df['BED_UTILIZATION']
capacity_list = capacity_df.to_list()
capacity_list
# Out:
# [0.021347032999999998,
#  0.48808181,
#  0.51249999,
#  0.63547224,
#  0.64135385,
#  0.59720945,
#  0.62807184,
#  0.93281841,
#  0.39496374]

# %%
for i in range(len(coords_list)):
    
    #Add markers to the map
    #folium.Marker(coords_list[i], popup = hnames_list[i]).add_to(my_map)
    
    # Print coordinates for a sanity check
    #print(coords_list[i])
    
    # 
    cap_percent = round((capacity_list[i]*100),2)
    
    popup_string = hnames_list[i] + "\nCapacity at:\n" + str(cap_percent) +"%"
    
    folium.Marker(coords_list[i],popup=popup_string).add_to(my_map)

# %%
#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_map.save("../maps/denver-hospitals.html")
